# %%
# import libraries
import pandas as pd

# %%
import numpy as np

# %%
#Standardisation
#previewing first 5 records
#To seperate columns use ';'  

df= pd.read_csv("DataCleaningDataset.csv" , ';')
df.head()
# Out:
# C:\Users\HP 5330M\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 NAME        CITY         COUNTRY  HEIGHT  WEIGHT  ACCOUNT A  \
# 0          Adi Dako   LISBON       PORTUGAL           56   132.0     2390.0
# 1          John Paul   LONDON     UNITED KINGDOM      62   165.0     4500.0
# 2        Cindy Jules   Stockholm          Sweden      48   117.0        NaN
# 3      Arthur Kegels    BRUSSELS         BELGIUM      59   121.0     4344.0
# 4      Freya Bismark      Berlin        GERMANYY      53   126.0     7000.0
#
#    ACCOUNT B  TOTAL ACCOUNT
# 0       4340           6730
# 1      34334          38834
# 2       5504           8949
# 3       8999            300
# 4      19000          26000

# %%
#preview columns
df.columns
# Out:
# Index(['NAME', 'CITY', 'COUNTRY', 'HEIGHT', 'WEIGHT', 'ACCOUNT A', 'ACCOUNT B',
#        'TOTAL ACCOUNT'],
#       dtype='object')

# %%
#remove spaces using strip function
# convert the columns from capital letters to small letters
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
df.head()
# Out:
# C:\Users\HP 5330M\AppData\Local\Temp\ipykernel_7424\3233801957.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
# C:\Users\HP 5330M\AppData\Local\Temp\ipykernel_7424\3233801957.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')
#                 name        city         country  height  weight  account_a  \
# 0          Adi Dako   lisbon       PORTUGAL           56   132.0     2390.0
# ...

# %%
df= pd.read_csv("DataCleaningDataset.csv", ';')
df.columns = ['name', 'city', 'country', 'height', 'weight', 'account_a', 'account_b', 'total_account']
df.head()
# Out:
# C:\Users\HP 5330M\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3369: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                 name        city         country  height  weight  account_a  \
# 0          Adi Dako   LISBON       PORTUGAL           56   132.0     2390.0
# 1          John Paul   LONDON     UNITED KINGDOM      62   165.0     4500.0
# 2        Cindy Jules   Stockholm          Sweden      48   117.0        NaN
# 3      Arthur Kegels    BRUSSELS         BELGIUM      59   121.0     4344.0
# 4      Freya Bismark      Berlin        GERMANYY      53   126.0     7000.0
#
#    account_b  total_account
# 0       4340           6730
# 1      34334          38834
# 2       5504           8949
# 3       8999            300
# 4      19000          26000

# %%
df['city'] = df['city'].str.lower()
df.head()
# Out:
#                 name        city         country  height  weight  account_a  \
# 0          Adi Dako   lisbon       PORTUGAL           56   132.0     2390.0
# 1          John Paul   london     UNITED KINGDOM      62   165.0     4500.0
# 2        Cindy Jules   stockholm          Sweden      48   117.0        NaN
# 3      Arthur Kegels    brussels         BELGIUM      59   121.0     4344.0
# 4      Freya Bismark      berlin        GERMANYY      53   126.0     7000.0
#
#    account_b  total_account
# 0       4340           6730
# 1      34334          38834
# 2       5504           8949
# 3       8999            300
# 4      19000          26000

# %%
#convert height from feet to centimetres
df['height'] = df['height'] * 2.54
df.head()
# Out:
#                 name        city         country  height  weight  account_a  \
# 0          Adi Dako   lisbon       PORTUGAL       142.24   132.0     2390.0
# 1          John Paul   london     UNITED KINGDOM  157.48   165.0     4500.0
# 2        Cindy Jules   stockholm          Sweden  121.92   117.0        NaN
# 3      Arthur Kegels    brussels         BELGIUM  149.86   121.0     4344.0
# 4      Freya Bismark      berlin        GERMANYY  134.62   126.0     7000.0
#
#    account_b  total_account
# 0       4340           6730
# 1      34334          38834
# 2       5504           8949
# 3       8999            300
# 4      19000          26000

# %%
#check datatypes
df.dtypes
# Out:
# name              object
# city              object
# country           object
# height           float64
# weight           float64
# account_a        float64
# account_b          int64
# total_account      int64
# dtype: object

# %%
# Data types conversions
df['height'] = df['height'].apply(np.int64)
df.dtypes
# Out:
# name              object
# city              object
# country           object
# height             int64
# weight           float64
# account_a        float64
# account_b          int64
# total_account      int64
# dtype: object

# %%
df.sample(5)
# Out:
#                 name               city         country  height  weight  \
# 3      Arthur Kegels           brussels         BELGIUM     149   121.0
# 0          Adi Dako          lisbon       PORTUGAL          142   132.0
# 4      Freya Bismark             berlin        GERMANYY     134   126.0
# 7          John Paul          london     UNITED KINGDOM     157     NaN
# 5         Rena Filip       brasilia              BRAZIL     127   167.0
#
#    account_a  account_b  total_account
# 3     4344.0       8999            300
# 0     2390.0       4340           6730
# 4     7000.0      19000          26000
# 7     4500.0       2300           6800
# 5     4999.0       3999           3450

# %%
#Data cleaning, replace values
df['country'] = df['country'].str.replace('GERMANYY', 'GERMANY')
df.head()
# Out:
#                 name        city         country  height  weight  account_a  \
# 0          Adi Dako   lisbon       PORTUGAL          142   132.0     2390.0
# 1          John Paul   london     UNITED KINGDOM     157   165.0     4500.0
# 2        Cindy Jules   stockholm          Sweden     121   117.0        NaN
# 3      Arthur Kegels    brussels         BELGIUM     149   121.0     4344.0
# 4      Freya Bismark      berlin         GERMANY     134   126.0     7000.0
#
#    account_b  total_account
# 0       4340           6730
# 1      34334          38834
# 2       5504           8949
# 3       8999            300
# 4      19000          26000

# %%
df['city'] = df['city'].str.strip()
df['city']
# Out:
# 0       lisbon
# 1       london
# 2    stockholm
# 3     brussels
# 4       berlin
# 5     brasilia
# 6    stockholm
# 7       london
# Name: city, dtype: object

# %%
#Drop column city
df.drop(["city"], axis = 1, inplace = True)
df.head()
# Out:
#                 name         country  height  weight  account_a  account_b  \
# 0          Adi Dako    PORTUGAL          142   132.0     2390.0       4340
# 1          John Paul  UNITED KINGDOM     157   165.0     4500.0      34334
# 2        Cindy Jules          Sweden     121   117.0        NaN       5504
# 3      Arthur Kegels         BELGIUM     149   121.0     4344.0       8999
# 4      Freya Bismark         GERMANY     134   126.0     7000.0      19000
#
#    total_account
# 0           6730
# 1          38834
# 2           8949
# 3            300
# 4          26000

# %%
#convert values with capital letters to small letters 
df['country']= df['country']. str. lower()
df.head()
# Out:
#                 name         country  height  weight  account_a  account_b  \
# 0          Adi Dako    portugal          142   132.0     2390.0       4340
# 1          John Paul  united kingdom     157   165.0     4500.0      34334
# 2        Cindy Jules          sweden     121   117.0        NaN       5504
# 3      Arthur Kegels         belgium     149   121.0     4344.0       8999
# 4      Freya Bismark         germany     134   126.0     7000.0      19000
#
#    total_account
# 0           6730
# 1          38834
# 2           8949
# 3            300
# 4          26000

# %%
#look for null values
df.isnull().sum()
# Out:
# name             0
# country          0
# height           0
# weight           1
# account_a        1
# account_b        0
# total_account    0
# dtype: int64

# %%
#we can get the missing value in column account_a by subtracting total_account from account_b then replace it with that value
df['account_a'] = df['account_a'].fillna('3445')
df.head()
# Out:
#                 name         country  height  weight account_a  account_b  \
# 0          Adi Dako    portugal          142   132.0    2390.0       4340
# 1          John Paul  united kingdom     157   165.0    4500.0      34334
# 2        Cindy Jules          sweden     121   117.0      3445       5504
# 3      Arthur Kegels         belgium     149   121.0    4344.0       8999
# 4      Freya Bismark         germany     134   126.0    7000.0      19000
#
#    total_account
# 0           6730
# 1          38834
# 2           8949
# 3            300
# 4          26000

# %%
#The null value in the weight column row 7 is a duplicate of row 1 
df
# Out:
#                 name         country  height  weight account_a  account_b  \
# 0          Adi Dako    portugal          142   132.0    2390.0       4340
# 1          John Paul  united kingdom     157   165.0    4500.0      34334
# 2        Cindy Jules          sweden     121   117.0      3445       5504
# 3      Arthur Kegels         belgium     149   121.0    4344.0       8999
# 4      Freya Bismark         germany     134   126.0    7000.0      19000
# 5         Rena Filip          brazil     127   167.0    4999.0       3999
# 6        Cindy Jules          sweden     121   117.0    3445.0       5504
# 7          John Paul  united kingdom     157     NaN    4500.0       2300
#
#    total_account
# 0           6730
# 1          38834
# 2           8949
# 3            300
# 4          26000
# 5           3450
# 6           8949
# 7           6800

# %%
#Delete duplicates
df. T. drop_duplicates()
# Out:
#                            0               1            2                  3  \
# name               Adi Dako        John Paul  Cindy Jules      Arthur Kegels
# country        portugal       united kingdom       sweden            belgium
# height                   142             157          121                149
# weight                 132.0           165.0        117.0              121.0
# account_a             2390.0          4500.0         3445             4344.0
# account_b               4340           34334         5504               8999
# total_account           6730           38834         8949                300
#
#                            4           5            6               7
# name           Freya Bismark  Rena Filip  Cindy Jules       John Paul
# country              germany      brazil       sweden  united kingdom
# height                   134         127          121             157
# weight                 126.0       167.0        117.0             NaN
# ...

# %%
#Drop row duplicate rows
df.drop([0, 6,7])
# Out:
#                 name         country  height  weight account_a  account_b  \
# 1          John Paul  united kingdom     157   165.0    4500.0      34334
# 2        Cindy Jules          sweden     121   117.0      3445       5504
# 3      Arthur Kegels         belgium     149   121.0    4344.0       8999
# 4      Freya Bismark         germany     134   126.0    7000.0      19000
# 5         Rena Filip          brazil     127   167.0    4999.0       3999
#
#    total_account
# 1          38834
# 2           8949
# 3            300
# 4          26000
# 5           3450
